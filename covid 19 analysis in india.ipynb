# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import seaborn as sb

# %%
data = pd.read_csv("Latest Covid-19 India Status.csv")

# %%
data.head()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6214190  106809     5980350  127031              1.72
# 1          Kerala      3160937  125535     3020052   15350              3.97
# 2       Karnataka      2883947   29314     2818476   36157              1.02
# 3      Tamil Nadu      2535402   27897     2473781   33724              1.10
# 4  Andhra Pradesh      1940096   24708     1902256   13132              1.27
#
#    Discharge Ratio (%)  Death Ratio (%)
# 0                96.24             2.04
# 1                95.54             0.49
# 2                97.73             1.25
# 3                97.57             1.33
# 4                98.05             0.68

# %%
data.describe()
# Out:
#         Total Cases         Active    Discharged         Deaths  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000
# mean   8.651175e+05   11712.916667  8.419016e+05   11503.000000
# std    1.244523e+06   27062.566710  1.202299e+06   21914.699427
# min    7.510000e+03      16.000000  7.365000e+03       4.000000
# 25%    6.076375e+04     567.250000  5.888850e+04     788.750000
# 50%    4.469820e+05    1412.000000  4.328515e+05    5028.500000
# 75%    9.657078e+05    9713.000000  9.536130e+05   13223.000000
# max    6.214190e+06  125535.000000  5.980350e+06  127031.000000
#
#        Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# count         36.000000            36.000000        36.000000
# mean           2.572778            96.167778         1.260000
# std            4.495239             4.393510         0.562926
# min            0.030000            77.720000         0.040000
# 25%            0.155000            96.137500         0.932500
# ...

# %%
sb.relplot(x='Total Cases',y='State/UTs',height=15,aspect=1,data=data)

# %%
mpl.subplots(figsize=(15,9))
sb.barplot(x='Total Cases',y='State/UTs',data=data)

# %%
mpl.subplots(figsize=(15,9))
sb.barplot(x='Active',y='State/UTs',data=data)

# %%
mpl.subplots(figsize=(15,9))
sb.barplot(x='Deaths',y='State/UTs',data=data)

# %%
mpl.subplots(figsize=(15,9))
sb.barplot(x='Discharged',y='State/UTs',data=data)
